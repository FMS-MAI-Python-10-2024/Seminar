# %% [markdown]
# ## Задачник 1
#
# ### Решение предполагается после ознакомления с Introduction

# %% [markdown]
# ### Задание 1
#
# На вход подаётся список чисел, разделённых пробелами. Ваша задача - выяснить, какого знака будет произведение всех этих чисел. Если произведение положительное (x >= 0), то нужно вывести "Positive". В противном случае - выводим "Negative".
#
# Входные данные:
# Единственная строка длиной k, 1 <= k <= 10^5. Строка содержит числа, причём каждое число n принимает значения -10^5 <= n <= 10^5.
#
# Выходные данные:
# Единственная строка, содержащая ответ на задание.
#
# P.S. input() возвращает нам строку, а значит, методы строки можно применять и к нему.

# %%
# Решение

# %% [markdown]
# ### Задание 2
#
# На вход подётся список строк, разделённых ", ". Ваша задача узнать длину самой большой строки, которая есть в этом списке. Ответом на задачу будет являться номер строки и её длина соответсвенно. Формат вывода "Самая длинная строка хранится под номером: x. Её длина: l." Где x и l порядковый номер (не индекс, а номер), а l - длина.
#
# Входные данные: Единственная строка длиной k, 1 <= k <= 10^5. Строка содержит слова, длина кажого из которых l, 1 <= l <= 10^5.
#
# Выходные данные: Ответ на задачу в соответсвующем формате.
#
# P.S. Поминим, что разделять можно и по целому набору символов.
#
# P.P.S. Помним про f-строки.

# %%
# Решение

# %% [markdown]
# ### Задание 3
#
# На вход подаются три числа, разделённых пробелами - коэффициенты a, b и с уравнения вида: ax^2+bx+c=0. Ваша задача по данным коэффициентам узнать корни уравнения, если они есть и вывести их. Если корня два, необходимо вывести "Уравнение имеет два решения: x1 = p, x2 = q.", где p и q решения уравнения в порядке возрастания (p <= q). Если уравнение имеет одно решение, необходимо вывести "Уравнение имеет одно решение: x = p.", где p - решение этого уравнения. Если уравнение не имеет решений, то выводим "Уравнение не имеет решений.".
#
# Входные данные: Три числовых коэффициента a, b и c в формате одной строки. Коэффициенты разделены пробелами.
#
# Выходные данные: Ответ на задачу в заданном формате.
#
# P.S. Чтобы поменять значения переменных местами можно использовать запись a, b = b, a.

# %%
# Решение

# %% [markdown]
# ### Задание 4
#
# На вход подаётся строка текста, содержащая только латинские буквы, пробелы и знаки препинания. Ваша задача - узнать длину самого последнего слова в строке. Длиной слова считаются только буквы английского алфавита. Знаки препинания и пробелы учитывать не нужно. В строке также могут быть "висящие" пробелы.
#
# Пример строки: "     Hello,     World! "
#
# Ответ на пример: 5 (длина слова World равна 5).
#
# Входные данные: Строка текста длиной k, 1 <= k <= 10^7.
#
# Выходные данные: Число, длина искомого слова.

# %%
# Решение

# %% [markdown]
# ### Задание 5
#
# На вход подаётся матрица m на n, где m - количество строк матрицы, а n - количество колонок. Ваша задача - вывести элементы матрицы через пробел по спирали (начиная с левого верхнего угла и по часовой стрелке, двигаясь по спирали в сторону центра.
#
# Входные данные: m строк, каждая из которых содержит n чисел, разделённых пробелами.
#
#
# Выходные данные: Числа, разделённые пробелами в заданном порядке.

# %%
# Решение

# %% [markdown]
# Дополнительные задания:
#
# 1. Проверка строки на палиндром.
# 2. Возможность уместить список в матрицу m на n.
# 3. Локальные максимумы матрицы.
