# %% [markdown]
# ## Задачи на множества и словари
#
# Следует проходить после просмотра и ознакомления со множествами и словарями. Здесь представлены некоторые логические задания, на которых можно отработать синтаксис и понимание концепций данных структур в целом.

# %% [markdown]
#  ## Задание 1
#
# ### Сумма.
#
# На вход подаётся набор чисел nums и число target. Ваша задача выяснить, какие два числа при сложении дают target. Для решения задачи можно предположить, что такие числа точно находятся в данном списке чисел. Выведите индексы этих чисел (не значения, а индексы).
#
#
# Формат ввода: Первая строка содержит числа, которые входят в nums (числа разделены пробелами). Вторая строка содержит единственное число - target.
#
#
# Формат вывода: Единственная строка, содержащая два числа - индексы элементов, которые в сумме дают target.
#
#
# Примеры:
# nums = [2,7,11,15], target = 9
# Вывод: 0 1
#
# nums = [3,2,4], target = 6
# Вывод: 1 2
#
# nums = [3,3], target = 6
# Вывод: 0 1
#
#
# Ограничения:
# + 2 <= nums.length <= 10^4
# + -10^9 <= nums[i] <= 10^9
# + -10^9 <= target <= 10^9

# %%
# Решение

# %% [markdown]
# ## Задание 2.
#
# ### Первая уникальная буква в строке.
#
# На вход подаётся строка, состоящая из литер английского алфавита в нижнем регистре. Ваша задача - вывести индекс буквы, которая встречается в этой строке лишь единожды (уникальна, не имеет дубликатов). Если такой буквы нет - вывести -1.
#
# Формат ввода: Единственная строка, содержащая буквы английского алфавита.
#
# Формат вывода: Число, индекс первой уникальной буквы в строке.
#
# Примеры:
#
# s = "maiisgreat"
# Вывод: 0
#
# s = "aabb"
# Вывод: -1
#
# Ограничения:
# - 1 <= s.length <= 10^5
# - s содержит исключительно буквы английского алфавита в нижнем регистре.

# %%
# Решение

# %% [markdown]
# ## Задание 3.
#
# ### Топ K наиболее часто встречающихся чисел.
#
# На вход подаётся список чисел и число k. Ваша задача вывести топ k чисел, которые наиболее часто встречаются в наборе чисел (число и его количество через пробел).
#
# Формат ввода: Единственная строка содержит числа, разделённые пробелами.
#
# Формат вывода: K строк, в каждой из которых указано число и количество раз, сколько оно встречается (по убыванию частоты).
#
# Примеры:
#
# nums = [1,1,1,2,2,3], k = 2
# Вывод:
# 1 3
# 2 2
#
# Ограничения:
# + 1 <= nums.length <= 10^5
# + -10^4 <= nums[i] <= 10^4
# + 1 <= k <= len(nums)
# + Ответ уникален

# %%
# Решение

# %% [markdown]
# ## Задание 4*
#
# ### Наиболее длинная подстрока из уникальных элементов.
#
# На вход даётся строка, состоящая из английских букв в нижнем регистре. Ваша задача - вывести длину наиболее длинной подстроки, содержащей только уникальные буквы.
#
# Формат ввода: Единственная строка, содержащая буквы английского алфавита в нижнем регистре.
#
# Формат вывода: Число, ответ на задачу.
#
# Примеры:
#
# s = "abcabcbb"
# Вывод: 3
#
# s = "bbbbb"
# Вывод: 1
#
# s = "pwwkew"
# Вывод: 3
#
# Ограничения:
# + 0 <= s.length <= 5 * 10^4

# %%
 # Решение
